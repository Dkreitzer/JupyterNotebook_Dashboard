# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

#Importing this to automate the visualizations time created
from datetime import datetime

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
citylats = []
citylngs = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        citylats.append(lat_lng[0])
        citylngs.append(lat_lng[1])

        # Print the city count to confirm sufficient count
print(f"There are {len(cities)} cities saved")
print(f"There are {len(citylats)} lats saved")
# Out:
# There are 591 cities saved
# There are 591 lats saved

# %%
#################### Creating DataFrame #####################
# Creating empty colummns that will be populated when requesting data via API

temp_dict ={
    "City" : cities,
    "Lat" : citylats,
    "Lng" : citylngs,
    "Temp":"",
    "Humidity":"",
    "Cloudiness":"",
    "Wind Speed":"",
    "City ID":""}

tempDict = pd.DataFrame(temp_dict)
tempDict.head()
# Out:
#         City        Lat         Lng Temp Humidity Cloudiness Wind Speed  \
# 0      alofi -19.841863 -166.224335
# 1    ushuaia -75.941025  -29.861165
# 2  upernavik  88.256656  -55.703451
# 3   cidreira -37.671731  -42.347168
# 4   svarstad  61.949685   11.763699
#
#   City ID
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Perform API Calls

# %%
#################### OpenWeatherMap API Key #####################
# 
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key + "&q="

### Creating a timestamp so we know exactly when the request was made to gather the weather data
### The timestamp is in this cell specifically to capture the request time, that way visualizations can be made 'whenver'
### and it will still refer to the correct time for when the data was captured.
ts = pd.to_datetime(datetime.now())

#Creating Counters to keep track of cities with temp info and cities without temp info
city_number = 0
noinfo = 0

for index, row in tempDict.iterrows():
    city = row['City']
    
    #API Call
    response = requests.get(url + city).json()
    
    try:
       
        
        tempDict.loc[index, 'Temp'] = response['main']['temp']
        tempDict.loc[index, 'Humidity'] = response['main']['humidity']
        tempDict.loc[index, 'Cloudiness'] = response['clouds']['all']
        tempDict.loc[index, 'Wind Speed'] = response['wind']['speed']
        tempDict.loc[index, 'City ID'] = response['id']
        city_number +=1
        print(f"City Number: {city_number} - City Name: {city}")
    except KeyError:
        
#         print(f"{city} did not have a temp")
        noinfo +=1
        continue

print("---------------------------------")
print(f"There are {city_number} cities that DO have info")
print(f"there are {noinfo} cities that DO NOT have any info")
print("----------------------------------")
# Out:
# City Number: 1 - City Name: alofi
# City Number: 2 - City Name: ushuaia
# City Number: 3 - City Name: upernavik
# City Number: 4 - City Name: cidreira
# City Number: 5 - City Name: svarstad
# City Number: 6 - City Name: kibre mengist
# City Number: 7 - City Name: georgetown
# City Number: 8 - City Name: punta arenas
# City Number: 9 - City Name: lata
# City Number: 10 - City Name: egvekinot
# City Number: 11 - City Name: antalaha
# City Number: 12 - City Name: rikitea
# City Number: 13 - City Name: pierre
# City Number: 14 - City Name: mataura
# City Number: 15 - City Name: la ronge
# City Number: 16 - City Name: nikolskoye
# City Number: 17 - City Name: ormara
# City Number: 18 - City Name: mogadishu
# City Number: 19 - City Name: iqaluit
# City Number: 20 - City Name: dikson
# City Number: 21 - City Name: serrinha
# City Number: 22 - City Name: barrow
# City Number: 23 - City Name: champerico
# City Number: 24 - City Name: nanortalik
# City Number: 25 - City Name: burnie
# City Number: 26 - City Name: new norfolk
# City Number: 27 - City Name: port elizabeth
# City Number: 28 - City Name: lagoa
# City Number: 29 - City Name: tucuman
# City Number: 30 - City Name: busselton
# City Number: 31 - City Name: jamestown
# City Number: 32 - City Name: ribeira grande
# City Number: 33 - City Name: limon
# City Number: 34 - City Name: okha
# City Number: 35 - City Name: provideniya
# City Number: 36 - City Name: pevek
# City Number: 37 - City Name: longyearbyen
# City Number: 38 - City Name: marawi
# City Number: 39 - City Name: dudinka
# City Number: 40 - City Name: hovd
# City Number: 41 - City Name: namibe
# City Number: 42 - City Name: hilo
# City Number: 43 - City Name: berea
# City Number: 44 - City Name: seaforth
# City Number: 45 - City Name: cape town
# City Number: 46 - City Name: yellowknife
# City Number: 47 - City Name: avarua
# City Number: 48 - City Name: nhulunbuy
# City Number: 49 - City Name: boa vista
# City Number: 50 - City Name: cherskiy
# City Number: 51 - City Name: bredasdorp
# City Number: 52 - City Name: bluff
# City Number: 53 - City Name: sitka
# City Number: 54 - City Name: savelugu
# City Number: 55 - City Name: bathsheba
# City Number: 56 - City Name: polson
# City Number: 57 - City Name: parczew
# City Number: 58 - City Name: salalah
# City Number: 59 - City Name: cabo san lucas
# City Number: 60 - City Name: saskylakh
# City Number: 61 - City Name: tiksi
# City Number: 62 - City Name: mardin
# City Number: 63 - City Name: qaanaaq
# City Number: 64 - City Name: bethel
# City Number: 65 - City Name: albany
# City Number: 66 - City Name: katsuura
# City Number: 67 - City Name: williams lake
# City Number: 68 - City Name: vallenar
# City Number: 69 - City Name: mabaruma
# City Number: 70 - City Name: geraldton
# City Number: 71 - City Name: pisco
# City Number: 72 - City Name: lazaro cardenas
# City Number: 73 - City Name: mahajanga
# City Number: 74 - City Name: atuona
# City Number: 75 - City Name: plaridel
# City Number: 76 - City Name: henties bay
# City Number: 77 - City Name: tuktoyaktuk
# City Number: 78 - City Name: kapuskasing
# City Number: 79 - City Name: quatre cocos
# City Number: 80 - City Name: saint-philippe
# City Number: 81 - City Name: san jeronimo
# City Number: 82 - City Name: hermanus
# City Number: 83 - City Name: bosaso
# City Number: 84 - City Name: talnakh
# City Number: 85 - City Name: vaini
# City Number: 86 - City Name: ponta do sol
# City Number: 87 - City Name: sambava
# City Number: 88 - City Name: dicabisagan
# City Number: 89 - City Name: lebu
# City Number: 90 - City Name: impfondo
# City Number: 91 - City Name: arraial do cabo
# City Number: 92 - City Name: caravelas
# City Number: 93 - City Name: pangody
# City Number: 94 - City Name: marzuq
# City Number: 95 - City Name: coruripe
# City Number: 96 - City Name: waipawa
# City Number: 97 - City Name: deputatskiy
# City Number: 98 - City Name: tasiilaq
# City Number: 99 - City Name: hobart
# City Number: 100 - City Name: khatanga
# City Number: 101 - City Name: meulaboh
# City Number: 102 - City Name: puerto ayora
# City Number: 103 - City Name: poum
# City Number: 104 - City Name: touros
# City Number: 105 - City Name: khandyga
# City Number: 106 - City Name: kaseda
# City Number: 107 - City Name: saldanha
# City Number: 108 - City Name: nantucket
# City Number: 109 - City Name: arman
# City Number: 110 - City Name: hambantota
# City Number: 111 - City Name: morlaix
# City Number: 112 - City Name: husavik
# City Number: 113 - City Name: port-gentil
# City Number: 114 - City Name: torbay
# City Number: 115 - City Name: cayenne
# City Number: 116 - City Name: carbonia
# City Number: 117 - City Name: havelock
# City Number: 118 - City Name: puerto del rosario
# City Number: 119 - City Name: saint george
# City Number: 120 - City Name: griffith
# City Number: 121 - City Name: north bend
# City Number: 122 - City Name: canton
# City Number: 123 - City Name: garden city
# City Number: 124 - City Name: comodoro rivadavia
# City Number: 125 - City Name: dalbandin
# City Number: 126 - City Name: ilulissat
# City Number: 127 - City Name: liverpool
# City Number: 128 - City Name: coahuayana
# City Number: 129 - City Name: mareeba
# City Number: 130 - City Name: kapaa
# City Number: 131 - City Name: port alfred
# City Number: 132 - City Name: aklavik
# City Number: 133 - City Name: grindu
# City Number: 134 - City Name: white oak
# City Number: 135 - City Name: chifeng
# City Number: 136 - City Name: horki
# City Number: 137 - City Name: airai
# City Number: 138 - City Name: yerbogachen
# City Number: 139 - City Name: namatanai
# City Number: 140 - City Name: hualmay
# City Number: 141 - City Name: mozarlandia
# City Number: 142 - City Name: hithadhoo
# City Number: 143 - City Name: zhigansk
# City Number: 144 - City Name: wasilla
# City Number: 145 - City Name: dublin
# City Number: 146 - City Name: portland
# City Number: 147 - City Name: sur
# City Number: 148 - City Name: kavaratti
# City Number: 149 - City Name: bilma
# City Number: 150 - City Name: faanui
# City Number: 151 - City Name: roebourne
# City Number: 152 - City Name: butaritari
# City Number: 153 - City Name: east london
# City Number: 154 - City Name: lavrentiya
# City Number: 155 - City Name: luderitz
# City Number: 156 - City Name: yatou
# City Number: 157 - City Name: karoi
# City Number: 158 - City Name: cockburn town
# City Number: 159 - City Name: virginia beach
# City Number: 160 - City Name: tual
# City Number: 161 - City Name: mwene-ditu
# City Number: 162 - City Name: mahebourg
# City Number: 163 - City Name: monrovia
# City Number: 164 - City Name: thompson
# City Number: 165 - City Name: victoria
# City Number: 166 - City Name: dengzhou
# City Number: 167 - City Name: fairbanks
# City Number: 168 - City Name: hamilton
# City Number: 169 - City Name: klaksvik
# City Number: 170 - City Name: zhangye
# City Number: 171 - City Name: avera
# City Number: 172 - City Name: castro
# City Number: 173 - City Name: severomuysk
# City Number: 174 - City Name: yuzhnyy
# City Number: 175 - City Name: bubaque
# City Number: 176 - City Name: ahipara
# City Number: 177 - City Name: semey
# City Number: 178 - City Name: linxia
# City Number: 179 - City Name: pitimbu
# City Number: 180 - City Name: hami
# City Number: 181 - City Name: constitucion
# City Number: 182 - City Name: kindu
# City Number: 183 - City Name: norman wells
# City Number: 184 - City Name: camopi
# City Number: 185 - City Name: dandong
# City Number: 186 - City Name: kodiak
# City Number: 187 - City Name: lisakovsk
# City Number: 188 - City Name: kyabram
# City Number: 189 - City Name: pangoa
# City Number: 190 - City Name: pasighat
# City Number: 191 - City Name: phan thiet
# City Number: 192 - City Name: vizinga
# City Number: 193 - City Name: pocos de caldas
# City Number: 194 - City Name: narsaq
# City Number: 195 - City Name: ostrovnoy
# City Number: 196 - City Name: necochea
# City Number: 197 - City Name: hohhot
# City Number: 198 - City Name: huarmey
# City Number: 199 - City Name: mahibadhoo
# City Number: 200 - City Name: barabai
# City Number: 201 - City Name: great yarmouth
# City Number: 202 - City Name: xining
# City Number: 203 - City Name: pacifica
# City Number: 204 - City Name: kidal
# City Number: 205 - City Name: mar del plata
# City Number: 206 - City Name: beckley
# City Number: 207 - City Name: tabuk
# City Number: 208 - City Name: voznesenye
# City Number: 209 - City Name: lorengau
# City Number: 210 - City Name: port macquarie
# City Number: 211 - City Name: coquimbo
# City Number: 212 - City Name: sao filipe
# City Number: 213 - City Name: college
# City Number: 214 - City Name: ballitoville
# City Number: 215 - City Name: le port
# City Number: 216 - City Name: wenling
# City Number: 217 - City Name: clyde river
# City Number: 218 - City Name: cuamba
# City Number: 219 - City Name: dhadar
# City Number: 220 - City Name: altagracia de orituco
# City Number: 221 - City Name: pulandian
# City Number: 222 - City Name: chokurdakh
# City Number: 223 - City Name: haines junction
# City Number: 224 - City Name: mayo
# City Number: 225 - City Name: vostok
# City Number: 226 - City Name: southbridge
# City Number: 227 - City Name: marsh harbour
# City Number: 228 - City Name: esperance
# City Number: 229 - City Name: saint-joseph
# City Number: 230 - City Name: vila
# City Number: 231 - City Name: la palma
# City Number: 232 - City Name: pangnirtung
# City Number: 233 - City Name: kavieng
# City Number: 234 - City Name: mae chan
# City Number: 235 - City Name: batesville
# City Number: 236 - City Name: oksfjord
# City Number: 237 - City Name: camacha
# City Number: 238 - City Name: high level
# City Number: 239 - City Name: kragero
# City Number: 240 - City Name: watsa
# City Number: 241 - City Name: crib point
# City Number: 242 - City Name: lasa
# City Number: 243 - City Name: port blair
# City Number: 244 - City Name: rockland
# City Number: 245 - City Name: carnot
# City Number: 246 - City Name: yar-sale
# City Number: 247 - City Name: awjilah
# City Number: 248 - City Name: hasaki
# City Number: 249 - City Name: soloneshnoye
# City Number: 250 - City Name: vestmannaeyjar
# City Number: 251 - City Name: jiangyou
# City Number: 252 - City Name: katangli
# City Number: 253 - City Name: miri
# City Number: 254 - City Name: nuuk
# City Number: 255 - City Name: lompoc
# City Number: 256 - City Name: dingle
# City Number: 257 - City Name: saint-augustin
# City Number: 258 - City Name: solnechnyy
# City Number: 259 - City Name: teknaf
# City Number: 260 - City Name: carnarvon
# City Number: 261 - City Name: beringovskiy
# City Number: 262 - City Name: havoysund
# City Number: 263 - City Name: nova prata
# City Number: 264 - City Name: tambacounda
# City Number: 265 - City Name: vagur
# City Number: 266 - City Name: nieuw amsterdam
# City Number: 267 - City Name: yaan
# City Number: 268 - City Name: port augusta
# City Number: 269 - City Name: port lincoln
# City Number: 270 - City Name: rundu
# City Number: 271 - City Name: itupiranga
# City Number: 272 - City Name: tabou
# City Number: 273 - City Name: naze
# City Number: 274 - City Name: tabas
# City Number: 275 - City Name: challans
# City Number: 276 - City Name: te anau
# City Number: 277 - City Name: kargasok
# City Number: 278 - City Name: vestmanna
# City Number: 279 - City Name: omboue
# City Number: 280 - City Name: dong hoi
# City Number: 281 - City Name: dunedin
# City Number: 282 - City Name: kamenka
# City Number: 283 - City Name: muli
# City Number: 284 - City Name: oistins
# City Number: 285 - City Name: chara
# City Number: 286 - City Name: sibolga
# City Number: 287 - City Name: coari
# City Number: 288 - City Name: atambua
# City Number: 289 - City Name: surazh
# City Number: 290 - City Name: tilichiki
# City Number: 291 - City Name: sesheke
# City Number: 292 - City Name: mount isa
# City Number: 293 - City Name: doha
# City Number: 294 - City Name: barra da estiva
# City Number: 295 - City Name: akureyri
# City Number: 296 - City Name: guerrero negro
# City Number: 297 - City Name: great falls
# City Number: 298 - City Name: namie
# City Number: 299 - City Name: haapiti
# City Number: 300 - City Name: wagar
# City Number: 301 - City Name: namtsy
# City Number: 302 - City Name: severo-kurilsk
# City Number: 303 - City Name: dekar
# City Number: 304 - City Name: lima
# City Number: 305 - City Name: bemidji
# City Number: 306 - City Name: anadyr
# City Number: 307 - City Name: rock sound
# City Number: 308 - City Name: fortuna
# City Number: 309 - City Name: mount gambier
# City Number: 310 - City Name: ankang
# City Number: 311 - City Name: barcelos
# City Number: 312 - City Name: talaya
# City Number: 313 - City Name: shagamu
# City Number: 314 - City Name: oussouye
# City Number: 315 - City Name: komsomolskiy
# City Number: 316 - City Name: khorinsk
# City Number: 317 - City Name: udachnyy
# City Number: 318 - City Name: hobyo
# City Number: 319 - City Name: la asuncion
# City Number: 320 - City Name: mocuba
# City Number: 321 - City Name: gudalur
# City Number: 322 - City Name: petropavlovsk-kamchatskiy
# City Number: 323 - City Name: madison
# City Number: 324 - City Name: ivanava
# City Number: 325 - City Name: sao joao da barra
# City Number: 326 - City Name: trinidad
# City Number: 327 - City Name: worland
# City Number: 328 - City Name: shimoda
# City Number: 329 - City Name: lagunas
# City Number: 330 - City Name: paris
# City Number: 331 - City Name: abonnema
# City Number: 332 - City Name: charters towers
# City Number: 333 - City Name: lovozero
# City Number: 334 - City Name: liberal
# City Number: 335 - City Name: eyl
# City Number: 336 - City Name: isilkul
# City Number: 337 - City Name: yumen
# City Number: 338 - City Name: jardim
# City Number: 339 - City Name: port jervis
# City Number: 340 - City Name: paita
# City Number: 341 - City Name: palmares do sul
# City Number: 342 - City Name: atbasar
# City Number: 343 - City Name: aras
# City Number: 344 - City Name: circleville
# City Number: 345 - City Name: rio claro
# City Number: 346 - City Name: conroe
# City Number: 347 - City Name: mudgee
# City Number: 348 - City Name: barra patuca
# City Number: 349 - City Name: vao
# City Number: 350 - City Name: kandrian
# City Number: 351 - City Name: harjavalta
# City Number: 352 - City Name: bogorodskoye
# City Number: 353 - City Name: altay
# City Number: 354 - City Name: cedar city
# City Number: 355 - City Name: naliya
# City Number: 356 - City Name: vieux-habitants
# City Number: 357 - City Name: ishigaki
# City Number: 358 - City Name: sterling
# City Number: 359 - City Name: abnub
# City Number: 360 - City Name: labuhan
# City Number: 361 - City Name: nouadhibou
# City Number: 362 - City Name: aska
# City Number: 363 - City Name: qaqortoq
# City Number: 364 - City Name: yagodnoye
# City Number: 365 - City Name: brigantine
# City Number: 366 - City Name: bida
# City Number: 367 - City Name: eydhafushi
# City Number: 368 - City Name: sept-iles
# City Number: 369 - City Name: padang
# City Number: 370 - City Name: uruzgan
# City Number: 371 - City Name: port hardy
# City Number: 372 - City Name: sheltozero
# City Number: 373 - City Name: launceston
# City Number: 374 - City Name: le moule
# City Number: 375 - City Name: neryungri
# City Number: 376 - City Name: progreso
# City Number: 377 - City Name: tchibanga
# City Number: 378 - City Name: chinsali
# City Number: 379 - City Name: siderno
# City Number: 380 - City Name: along
# City Number: 381 - City Name: eirunepe
# City Number: 382 - City Name: bambous virieux
# City Number: 383 - City Name: ixtapa
# City Number: 384 - City Name: oktyabrskoye
# City Number: 385 - City Name: caledon
# City Number: 386 - City Name: mehamn
# City Number: 387 - City Name: fereydun kenar
# City Number: 388 - City Name: puerto escondido
# City Number: 389 - City Name: kautokeino
# City Number: 390 - City Name: tres arroyos
# City Number: 391 - City Name: kaka
# City Number: 392 - City Name: kruisfontein
# City Number: 393 - City Name: half moon bay
# City Number: 394 - City Name: miramar
# City Number: 395 - City Name: karratha
# City Number: 396 - City Name: kainantu
# City Number: 397 - City Name: rocha
# City Number: 398 - City Name: deskati
# City Number: 399 - City Name: maun
# City Number: 400 - City Name: isangel
# City Number: 401 - City Name: tamale
# City Number: 402 - City Name: nakamura
# City Number: 403 - City Name: kayerkan
# City Number: 404 - City Name: buraydah
# City Number: 405 - City Name: sao miguel do araguaia
# City Number: 406 - City Name: pointe michel
# City Number: 407 - City Name: san andres
# City Number: 408 - City Name: sterlibashevo
# City Number: 409 - City Name: itaocara
# City Number: 410 - City Name: inhambane
# City Number: 411 - City Name: danilovka
# City Number: 412 - City Name: puerto ayacucho
# City Number: 413 - City Name: businga
# City Number: 414 - City Name: kaitangata
# City Number: 415 - City Name: bogoslovka
# City Number: 416 - City Name: shunyi
# City Number: 417 - City Name: praia
# City Number: 418 - City Name: turukhansk
# City Number: 419 - City Name: kasongo-lunda
# City Number: 420 - City Name: mackay
# City Number: 421 - City Name: calolbon
# City Number: 422 - City Name: laguna
# City Number: 423 - City Name: strezhevoy
# City Number: 424 - City Name: zharkent
# City Number: 425 - City Name: almaznyy
# City Number: 426 - City Name: aja
# City Number: 427 - City Name: manbij
# City Number: 428 - City Name: vila franca do campo
# City Number: 429 - City Name: mount darwin
# City Number: 430 - City Name: adrar

# %%
################## Summary of Data and how many cities were removed becuase they didn't have any data #################

# Replace empty strings in the Temp column with NaN
tempDict['Temp'].replace('',np.nan, inplace=True)

# Create new DF with only cities that have temperature data
Complete_WeatherDF = tempDict.dropna(subset=['Temp'])

print(f"The original tempDict Data Frame's shape is: {tempDict.shape}")
print(f"The new DataFrame including only valid cities with temperatures shape is: {Complete_WeatherDF.shape}")
print(f"There were {noinfo} cities in the original tempDict Data Frame that did not have any info.")
Complete_WeatherDF.head()
# Out:
# The original tempDict Data Frame's shape is: (650, 8)
# The new DataFrame including only valid cities with temperatures shape is: (583, 8)
# There were 67 cities in the original tempDict Data Frame that did not have any info.
#         City        Lat         Lng   Temp Humidity Cloudiness Wind Speed  \
# 0     albany -73.466862   99.826726  45.27       53         20      14.99
# 2      bluff -71.575184  164.666982  83.47       44         32      15.66
# 3    ushuaia -80.323472  -25.707638  41.00       80         90      35.57
# 4  esperance -55.340878  126.737914  78.80       94         20       4.59
# 5    qaanaaq  85.794817  -92.793480  -4.15      100          0       8.16
#
#    City ID
# 0  5106834
# 2  2175403
# 3  3833367
# 4  3573739
# 5  3831208

# %%
############### Saving Data Frame to CSV File #########################

### This CSF file shows ONLY the cities that returned valid temperatures and were used for the visualizations below
Complete_WeatherDF.to_csv('Complete_WeatherDF.csv')

### This CSV file shows all of the cities that were originally generated, including those that did not return a temperature.
tempDict.to_csv('tempDict_DF.csv')

# %%
############## Temperature vs Latitude #######################
y = Complete_WeatherDF.Temp
x = Complete_WeatherDF.Lat
plt.scatter(x,y,marker = 'o')
plt.title(f"Temperature(F) vs. Latitude\nTime Stamp: {ts}")
plt.xlabel('Latitude')
plt.ylabel('Temperature(F)')
plt.savefig('WeatherPy_Temp.vs.Lat.png')
plt.show()

# %%
############## Humidity vs Latitude #######################
y = Complete_WeatherDF.Humidity
x = Complete_WeatherDF.Lat
plt.scatter(x,y,marker = 'o')
plt.title(f'Humidity(%) vs. Latitude\nTime Stamp: {ts}')
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
### Note for ylim - I added the ylim because sometimes a city would pull back a humidity percentage that was greater than
### 100% and it would distort the visualization...
plt.ylim(0,110)
plt.savefig('WeatherPy_Humidity.vs.Lat.png')
plt.show()

# %%
############## Cloudiness vs Latitude #######################
y = Complete_WeatherDF.Cloudiness
x = Complete_WeatherDF.Lat
plt.scatter(x,y,marker = 'o')
plt.title(f'Cloudiness(%) vs. Latitude\nTime Stamp: {ts}')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.savefig('WeatherPy_Cloudiness.vs.Lat.png')
plt.show()

# %%
############## WindSpeed vs Latitude #######################
y = Complete_WeatherDF['Wind Speed']
x = Complete_WeatherDF.Lat
plt.scatter(x,y,marker = 'o')
plt.title(f'Wind Speed (mph) vs. Latitude\nTime Stamp: {ts}')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
plt.savefig('WeatherPy_WindSpeed.vs.Lat.png')
plt.show()
